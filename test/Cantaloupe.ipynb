# %% [markdown]
# # Melon Cantaloupe from USDA, Frida and NEVO

# %%
all_sources.head()
# Out:
#   Source      Product_description  Protein_g  Total_lipid_g  \
# 0   USDA  Melons, cantaloupe, raw       0.82           0.18
# 1   NEVO         Melon cantaloupe       0.80           0.20
# 2  Frida    Melon, cantaloup, raw       0.80           0.20
#
#    Carbohydrate_by_difference_g  Ash_g  Energy_kcal  Sucrose_g  Glucose_g  \
# 0                          8.16   0.63           38       3.32       2.08
# 1                          7.90   0.70           38        NaN        NaN
# 2                          8.20   0.70           36       4.35       1.54
#
#    Fructose_g  Lactose_g  Maltose_g  Alcohol_g  Water_g  Sugars_total_g  \
# 0        2.40        0.0       0.02        NaN     90.2            7.88
# 1         NaN        NaN        NaN        0.0     90.2            7.90
# 2        1.87        0.0       0.04        0.0     90.2            7.86
#
#    Galactose_g  Fiber_dietary_g  Calcium_Ca_mg  Iron_Fe_mg  Magnesium_Mg_mg  \
# ...

# %% [markdown]
# # Descriptive statistics

# %%
all_sources.describe()
# Out:
#        Protein_g  Total_lipid_g  Carbohydrate_by_difference_g     Ash_g  \
# count   3.000000       3.000000                      3.000000  3.000000
# mean    0.806667       0.193333                      8.086667  0.676667
# std     0.011547       0.011547                      0.162891  0.040415
# min     0.800000       0.180000                      7.900000  0.630000
# 25%     0.800000       0.190000                      8.030000  0.665000
# 50%     0.800000       0.200000                      8.160000  0.700000
# 75%     0.810000       0.200000                      8.180000  0.700000
# max     0.820000       0.200000                      8.200000  0.700000
#
#        Energy_kcal  Sucrose_g  Glucose_g  Fructose_g  Lactose_g  Maltose_g  \
# count     3.000000    2.00000   2.000000    2.000000        2.0   2.000000
# mean     37.333333    3.83500   1.810000    2.135000        0.0   0.030000
# std       1.154701    0.72832   0.381838    0.374767        0.0   0.014142
# ...

# %% [markdown]
# # Visualization

# %%
barplot = sns.barplot(x = "Source", y = "Carotene_beta_mug", data = all_sources)
barplot.set(xlabel = "Sources", ylabel = "Carotene beta (µg ) ", title = "Carotene Beta Among Data Sources")
# Out:
# [Text(0.5, 0, 'Sources'),
#  Text(0, 0.5, 'Carotene beta (µg ) '),
#  Text(0.5, 1.0, 'Carotene Beta Among Data Sources')]

# %%
barplot = sns.barplot(x = "Source", y = "Vitamin_C_mg", data = all_sources)
barplot.set(xlabel = "Sources", ylabel = "Vitamin C (mg ) ", title = "Vitamin C Among Data Sources")
# Out:
# [Text(0.5, 0, 'Sources'),
#  Text(0, 0.5, 'Vitamin C (mg ) '),
#  Text(0.5, 1.0, 'Vitamin C Among Data Sources')]

# %%
barplot = sns.barplot(x = "Source", y = "Vitamin_K1_mug", data = all_sources)
barplot.set(xlabel = "Sources", ylabel = "Vitamin K1 (µg ) ", title = "Vitamin K1 Among Data Sources")
# Out:
# [Text(0.5, 0, 'Sources'),
#  Text(0, 0.5, 'Vitamin K1 (µg ) '),
#  Text(0.5, 1.0, 'Vitamin K1 Among Data Sources')]

# %%
barplot = sns.barplot(x = "Source", y = "Vitamin_A_RAE", data = all_sources)
barplot.set(xlabel = "Sources", ylabel = "Vitamin A (RAE) ", title = "Vitamin A (RAE) Among Data Sources")
# Out:
# [Text(0.5, 0, 'Sources'),
#  Text(0, 0.5, 'Vitamin A (RAE) '),
#  Text(0.5, 1.0, 'Vitamin A Among Data Sources')]

# %% [markdown]
# **ATTENTION: In this case, Frida doesn't have Vitamin A (RAE), just Vitamin A (RE)**

# %%
barplot = sns.barplot(x = "Source", y = "Copper_Cu_mg", data = all_sources)
barplot.set(xlabel = "Sources", ylabel = "Copper,Cu (mg)", title = "Copper Among Data Sources")
# Out:
# [Text(0.5, 0, 'Sources'),
#  Text(0, 0.5, 'Copper,Cu (mg)'),
#  Text(0.5, 1.0, 'Copper Among Data Sources')]

# %%
barplot = sns.barplot(x = "Source", y = "Folate_mug", data = all_sources)
barplot.set(xlabel = "Sources", ylabel = "Folate (µg)", title = "Folate Among Data Sources")
# Out:
# [Text(0.5, 0, 'Sources'),
#  Text(0, 0.5, 'Folate (µg)'),
#  Text(0.5, 1.0, 'Folate Among Data Sources')]

# %%
barplot = sns.barplot(x = "Source", y = "Iron_Fe_mg", data = all_sources)
barplot.set(xlabel = "Sources", ylabel = "Iron, Fe (mg)", title = "Iron Among Data Sources")
# Out:
# [Text(0.5, 0, 'Sources'),
#  Text(0, 0.5, 'Iron, Fe (mg)'),
#  Text(0.5, 1.0, 'Iron Among Data Sources')]

# %%
barplot = sns.barplot(x = "Source", y = "Phosphorus_P_mg", data = all_sources)
barplot.set(xlabel = "Sources", ylabel = "Phosphorus,P (mg)", title = "Phosphorus Among Data Sources")
# Out:
# [Text(0.5, 0, 'Sources'),
#  Text(0, 0.5, 'Phosphorus,P (mg)'),
#  Text(0.5, 1.0, 'Phosphorus Among Data Sources')]

# %%
barplot = sns.barplot(x = "Source", y = "Potassium_K_mg", data = all_sources)
barplot.set(xlabel = "Sources", ylabel = "Potassium K (mg)", title = "Potassium Among Data Sources")
# Out:
# [Text(0.5, 0, 'Sources'),
#  Text(0, 0.5, 'Potassium K (mg)'),
#  Text(0.5, 1.0, 'Potassium Among Data Sources')]

# %%
barplot = sns.barplot(x = "Source", y = "Sodium_Na_mg", data = all_sources)
barplot.set(xlabel = "Sources", ylabel = "Sodium, Na (mg)", title = "Sodium Among Data Sources")
# Out:
# [Text(0.5, 0, 'Sources'),
#  Text(0, 0.5, 'Sodium, Na (mg)'),
#  Text(0.5, 1.0, 'Sodium Among Data Sources')]

# %%
barplot = sns.barplot(x = "Source", y = "Zinc_Zn_mg", data = all_sources)
barplot.set(xlabel = "Sources", ylabel = "Zinc, Zn (mg)", title = "Zinc Among Data Sources")
# Out:
# [Text(0.5, 0, 'Sources'),
#  Text(0, 0.5, 'Zinc, Zn (mg)'),
#  Text(0.5, 1.0, 'Zinc Among Data Sources')]

# %%
barplot = sns.barplot(x = "Source", y = "Vitamin_B6_mg", data = all_sources)
barplot.set(xlabel = "Sources", ylabel = "Vitamin B6 (mg)", title = "Vitamin B6 Among Data Sources")
# Out:
# [Text(0.5, 0, 'Sources'),
#  Text(0, 0.5, 'Vitamin B6 (mg)'),
#  Text(0.5, 1.0, 'Vitamin B6 Among Data Sources')]
