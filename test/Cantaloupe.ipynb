# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
d = {
"Source":"Frida", "Product_description":"Melon, cantaloup, raw", "Protein_g":0.8, "Total_lipid_g":0.2, "Carbohydrate_by_difference_g":8.2, "Ash_g": 0.7 
, "Energy_kcal":36, "Sucrose_g":4.35, "Glucose_g":1.54, "Fructose_g":1.87, "Lactose_g":0, "Maltose_g":0.0400, "Alcohol_g":0, "Water_g":90.2
, "Sugars_total_g":7.86, "Galactose_g":0.06, "Fiber_dietary_g":0.9, "Calcium_Ca_mg":9.02, "Iron_Fe_mg":0.210
, "Magnesium_Mg_mg":12.0, "Phosphorus_P_mg":38.9, "Potassium_K_mg":267, "Sodium_Na_mg":16, "Zinc_Zn_mg":0.180, "Copper_Cu_mg":0.0410, "Manganese_Mn_mg":0.0410
, "Selenium_Se_mug":0, "Retinol_mug":0, "Vitamin_A_RAE":"", "Vitamin_A_RE":2.00, "Carotene_beta_mug":24, "Carotene_alpha_mug":""
, "Vitamin_E_mg":"", "Vitamin_D_mug":0, "Vitamin_D_(D2 + D3)_mg":"", "Cryptoxanthin_beta":"", "Lycopene":""
, "Lutein_+_zeaxanthin_mug":"", "Vitamin_C_mg":27.8, "Thiamin_mg":"", "Riboflavin_mg":0.0190, "Niacin_NE":0.768, "Pantothenic_acid_mg":0.105
, "Vitamin_B6_mg":0.0720, "Folate_mug":21.0, "Vitamin_B12":0, "Choline_mg":"", "Vitamin_K1_mug":0, "Folic_acid":""
, "Folate_mug":21.0, "Betaine_g":"", "Threonine_g":0.017, "Isoleucine_g":0.021, "Leucine_g":0.029, "Lysine_g":"", "Valine_g":0.034
, "Vitamin_E_alpha_TE":0.140, "Vitamin_B12_mug":0, "Cholesterol_mg":0, "Fatty_acids_conversion_factor_FCF":0.700,"Fatty_total_g":0.2
}

frida_cantaloupe = pd.DataFrame(data=d, index=[0])
#frida_cantaloupe

# %%
d = {
"Source":"NEVO", "Product_description":"Melon cantaloupe", "Protein_g":0.8, "Total_lipid_g":0.2, "Carbohydrate_by_difference_g":7.9, "Ash_g": 0.7 
, "Energy_kcal":38, "Sucrose_g":"", "Glucose_g":"", "Fructose_g":"", "Lactose_g":"", "Maltose_g":"", "Alcohol_g":0, "Water_g":90.2
, "Sugars_total_g":7.9, "Galactose_g":"", "Fiber_dietary_g":0.9, "Calcium_Ca_mg":9, "Iron_Fe_mg":0.2
, "Magnesium_Mg_mg":12, "Phosphorus_P_mg":15, "Potassium_K_mg":267, "Sodium_Na_mg":16, "Zinc_Zn_mg":0.18, "Copper_Cu_mg":0.04, "Manganese_Mn_mg":""
, "Selenium_Se_mug":0, "Retinol":"", "Vitamin_A_RAE":169, "Vitamin_A_RE_mug":338.0 ,"Carotene_beta_mug":2020.0, "Carotene_alpha_mug":16.0
, "Vitamin_E_mg":0.1, "Vitamin_D_mug":0, "Vitamin_D_(D2 + D3)_mg":"", "Cryptoxanthin_beta_mug":1.0, "Lycopene":0
, "Lutein_+_zeaxanthin_mug":"", "Vitamin_C_mg":37, "Thiamin_mg":0.04, "Riboflavin_mg":0.02, "Niacin_mg":0.7, "Pantothenic_acid_mg":""
, "Vitamin_B6_mg":0.072, "Folate_mug":21, "Vitamin_B12_mug":0, "Choline_mg":"", "Vitamin_K1_mug":2.5, "Folic_acid":0
, "Folate_mug":21, "Betaine_g":"", "Threonine_g":"", "Isoleucine_g":"", "Leucine_g":"", "Lysine_g":"", "Valine_g":""
, "Vitamin_E_alpha_TE":"", "Vitamin_B12_mug":0, "Cholesterol_mg":"", "Fatty_acids_conversion_factor_FCF":"","Fatty_total_g":0.2
}

nevo_cantaloupe = pd.DataFrame(data=d, index=[0])
#nevo_cantaloupes

# %%
d = {
"Source":"USDA", "Product_description":"Melons, cantaloupe, raw", "Protein_g":0.82, "Total_lipid_g":0.18, "Carbohydrate_by_difference_g":8.16, "Ash_g": 0.63 
, "Energy_kcal":38, "Sucrose_g":3.32, "Glucose_g":2.08, "Fructose_g":2.4, "Lactose_g":0, "Maltose_g":0.02, "Alcohol_g":"", "Water_g":90.2
, "Sugars_total_g":7.88, "Galactose_g":0.06, "Fiber_dietary_g":0.8, "Calcium_Ca_mg":9, "Iron_Fe_mg":0.38
, "Magnesium_Mg_mg":13, "Phosphorus_P_mg":17, "Potassium_K_mg":157, "Sodium_Na_mg":30, "Zinc_Zn_mg":0.44, "Copper_Cu_mg":0.085, "Manganese_Mn_mg":0.046
, "Selenium_Se_mug":1.7, "Retinol":"", "Vitamin_A_RAE":232, "Vitamin_A_RE_mug":"", "Carotene_beta_mug":2780, "Carotene_alpha_mug":0
, "Vitamin_E_mg":"", "Vitamin_D_mug":"", "Vitamin_D_(D2 + D3)_mg":"", "Cryptoxanthin_beta":0, "Lycopene_mug":0
, "Lutein_+_zeaxanthin_mug":32, "Vitamin_C_mg":10.9, "Thiamin_mg":0.049, "Riboflavin_mg":0.027, "Niacin_mg":0.694, "Pantothenic_acid_mg":0.085
, "Vitamin_B6_mg":0.04, "Folate_mug":14, "Vitamin_B12":"", "Choline_mg":"", "Vitamin_K1_mug":2.7, "Folic_acid":""
, "Folate_mug":14, "Betaine":"", "Threonine_g":0.14, "Isoleucine_g":0.017, "Leucine_g":0.024, "Lysine_g":0.024, "Valine_g":0.027
, "Vitamin_E_alpha_TE":"", "Vitamin_B12_mug":"", "Cholesterol_mg":"", "Fatty_acids_conversion_factor_FCF":"","Fatty_total_g":""
}

usda_cantaloupe= pd.DataFrame(data=d, index=[0])
#usda_cantaloupe

# %%
frames = [usda_cantaloupe, nevo_cantaloupe, frida_cantaloupe]

all_sources = pd.concat(frames)
all_sources
# Out:
#   Source      Product_description  Protein_g  Total_lipid_g  \
# 0   USDA  Melons, cantaloupe, raw       0.82           0.18
# 0   NEVO         Melon cantaloupe       0.80           0.20
# 0  Frida    Melon, cantaloup, raw       0.80           0.20
#
#    Carbohydrate_by_difference_g  Ash_g  Energy_kcal Sucrose_g Glucose_g  \
# 0                          8.16   0.63           38      3.32      2.08
# 0                          7.90   0.70           38
# 0                          8.20   0.70           36      4.35      1.54
#
#   Fructose_g Lactose_g Maltose_g Alcohol_g  Water_g  Sugars_total_g  \
# 0        2.4         0      0.02               90.2            7.88
# 0                                        0     90.2            7.90
# 0       1.87         0      0.04         0     90.2            7.86
#
#   Galactose_g  Fiber_dietary_g  Calcium_Ca_mg  Iron_Fe_mg  Magnesium_Mg_mg  \
# 0        0.06              0.8           9.00        0.38             13.0
# ...

# %%
all_sources.describe()
# Out:
#        Protein_g  Total_lipid_g  Carbohydrate_by_difference_g     Ash_g  \
# count   3.000000       3.000000                      3.000000  3.000000
# mean    0.806667       0.193333                      8.086667  0.676667
# std     0.011547       0.011547                      0.162891  0.040415
# min     0.800000       0.180000                      7.900000  0.630000
# 25%     0.800000       0.190000                      8.030000  0.665000
# 50%     0.800000       0.200000                      8.160000  0.700000
# 75%     0.810000       0.200000                      8.180000  0.700000
# max     0.820000       0.200000                      8.200000  0.700000
#
#        Energy_kcal  Water_g  Sugars_total_g  Fiber_dietary_g  Calcium_Ca_mg  \
# count     3.000000      3.0            3.00         3.000000       3.000000
# mean     37.333333     90.2            7.88         0.866667       9.006667
# std       1.154701      0.0            0.02         0.057735       0.011547
# ...

# %%
all_sources[["Carbohydrate_by_difference_g","Carotene_beta_mug" ]].plot.box()
# Out:
# <AxesSubplot:>

# %%
all_sources.plot.scatter(x="Source", y="Carotene_beta_mug", s=100)
# Out:
# <AxesSubplot:xlabel='Source', ylabel='Carotene_beta_mug'>

# %%
all_sources.plot.bar(stacked=True);

# %%
pwd()
# Out:
# '/home/jessicambs/BASF - Nutrient profiling/test'

# %%
result.to_csv(r'/home/jessicambs/BASF - Nutrient profiling/test/cantaloupe.csv', index = False)
